# %%
import pandas as pd
import numpy as np
import matplotlib as plt
df= pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\CustomerShopingData.csv")

# %%
df.rename(columns={'shopping_mall':'Shopping mall'}, inplace = True)

# %%
df[df['age']>=69]
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 8        I293455     C159642    Male   69         Clothing         3   900.24
# 77       I115870     C135790  Female   69            Shoes         4  2400.68
# 211      I226172     C171154  Female   69            Shoes         1   600.17
# 212      I737630     C848969    Male   69         Clothing         5  1500.40
# 282      I263818     C336232    Male   69         Souvenir         4    46.92
# ...          ...         ...     ...  ...              ...       ...      ...
# 98796    I146016     C203641  Female   69       Technology         2  2100.00
# 98839    I214432     C685875    Male   69             Toys         4   143.36
# 99007    I173132     C955663  Female   69         Clothing         3   900.24
# 99043    I482625     C274732  Female   69        Cosmetics         1    40.66
# 99321    I234667     C321665    Male   69  Food & Beverage         1     5.23
#
# ...

# %%
df.notnull().sum()
# Out:
# invoice_no        99457
# customer_id       99457
# gender            99457
# age               99457
# category          99457
# quantity          99457
# price             99457
# payment_method    99457
# invoice_date      99457
# Shopping mall     99457
# dtype: int64

# %%
df.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# Shopping mall     0
# dtype: int64

# %%
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   Shopping mall
# 0    Credit Card   05/08/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash   09/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
df.sample(10)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 59018    I155778     C318148  Female   56             Toys         2    71.68
# 9912     I240844     C135002  Female   24            Shoes         1   600.17
# 65873    I241506     C189754    Male   23  Food & Beverage         1     5.23
# 69062    I934437     C320809  Female   44            Books         5    75.75
# 78649    I171235     C132736  Female   46  Food & Beverage         3    15.69
# 52639    I325476     C331988  Female   41        Cosmetics         1    40.66
# 27209    I205354     C872482  Female   30            Shoes         3  1800.51
# 4830     I178134     C231298    Male   41         Clothing         4  1200.32
# 14540    I249941     C172759  Female   39       Technology         5  5250.00
# 34826    I468353     C316224    Male   67         Souvenir         3    35.19
#
#       payment_method invoice_date     Shopping mall
# 59018    Credit Card   16/03/2022    Viaport Outlet
# ...

# %%
df.age.describe()
# Out:
# count    99457.000000
# mean        43.427089
# std         14.990054
# min         18.000000
# 25%         30.000000
# 50%         43.000000
# 75%         56.000000
# max         69.000000
# Name: age, dtype: float64

# %%
df.age.mean()
# Out:
# 43.42708909377922

# %%
df.shape
# Out:
# (99457, 10)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=99457, step=1)

# %%
##columns names
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
##Data Types
df.dtypes
# Out:
# invoice_no         object
# customer_id        object
# gender             object
# age                 int64
# category           object
# quantity            int64
# price             float64
# payment_method     object
# invoice_date       object
# shopping_mall      object
# dtype: object

# %%
##Number of Unique records
df.nunique()
# Out:
# invoice_no        99457
# customer_id       99457
# gender                2
# age                  52
# category              8
# quantity              5
# price                40
# payment_method        3
# invoice_date        797
# shopping_mall        10
# dtype: int64

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.count()
# Out:
# invoice_no        99457
# customer_id       99457
# gender            99457
# age               99457
# category          99457
# quantity          99457
# price             99457
# payment_method    99457
# invoice_date      99457
# shopping_mall     99457
# dtype: int64

# %%
df.count().isnull()
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price             False
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %%
##count the number of  each item in a given column
df['gender'].value_counts()
# Out:
# gender
# Female    59482
# Male      39975
# Name: count, dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Clothing           34487
# Cosmetics          15097
# Food & Beverage    14776
# Toys               10087
# Shoes              10034
# Souvenir            4999
# Technology          4996
# Books               4981
# Name: count, dtype: int64

# %%
##information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
##statistical information about the data
df.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
df['age'].describe()
# Out:
# count    99457.000000
# mean        43.427089
# std         14.990054
# min         18.000000
# 25%         30.000000
# 50%         43.000000
# 75%         56.000000
# max         69.000000
# Name: age, dtype: float64

# %%
df.nunique()
# Out:
# invoice_no        99457
# customer_id       99457
# gender                2
# age                  52
# category              8
# quantity              5
# price                40
# payment_method        3
# invoice_date        797
# shopping_mall        10
# dtype: int64

# %%
df['payment_method'].unique()
# Out:
# array(['Credit Card', 'Debit Card', 'Cash'], dtype=object)

# %%
df.payment_method.value_counts()
# Out:
# payment_method
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: count, dtype: int64

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: count, dtype: int64

# %%
##filtering

df[df.gender=='Male']
# Out:
#       invoice_no customer_id gender  age         category  quantity    price  \
# 1        I317333     C111565   Male   21            Shoes         3  1800.51
# 2        I127801     C266599   Male   20         Clothing         1   300.08
# 8        I293455     C159642   Male   69         Clothing         3   900.24
# 13       I179802     C312861   Male   25         Clothing         2   600.16
# 15       I688768     C362288   Male   24            Shoes         5  3000.85
# ...          ...         ...    ...  ...              ...       ...      ...
# 99449    I134399     C953724   Male   65         Clothing         1   300.08
# 99451    I675411     C513603   Male   50             Toys         5   179.20
# 99453    I325143     C569580   Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292   Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631   Male   56       Technology         4  4200.00
#
# ...

# %%
df.groupby('gender').get_group('Female')
# Out:
#       invoice_no customer_id  gender  age   category  quantity    price  \
# 0        I138884     C241288  Female   28   Clothing         5  1500.40
# 3        I173702     C988172  Female   66      Shoes         5  3000.85
# 4        I337046     C189076  Female   53      Books         4    60.60
# 5        I227836     C657758  Female   28   Clothing         5  1500.40
# 6        I121056     C151197  Female   49  Cosmetics         1    40.66
# ...          ...         ...     ...  ...        ...       ...      ...
# 99447    I281214     C288090  Female   37       Toys         3   107.52
# 99448    I332105     C231387  Female   65      Shoes         4  2400.68
# 99450    I170504     C226974  Female   28      Books         1    15.15
# 99452    I219422     C441542  Female   45   Souvenir         5    58.65
# 99456    I232867     C273973  Female   36   Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# ...

# %%
df.groupby('gender').get_group('Male')
# Out:
#       invoice_no customer_id gender  age         category  quantity    price  \
# 1        I317333     C111565   Male   21            Shoes         3  1800.51
# 2        I127801     C266599   Male   20         Clothing         1   300.08
# 8        I293455     C159642   Male   69         Clothing         3   900.24
# 13       I179802     C312861   Male   25         Clothing         2   600.16
# 15       I688768     C362288   Male   24            Shoes         5  3000.85
# ...          ...         ...    ...  ...              ...       ...      ...
# 99449    I134399     C953724   Male   65         Clothing         1   300.08
# 99451    I675411     C513603   Male   50             Toys         5   179.20
# 99453    I325143     C569580   Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292   Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631   Male   56       Technology         4  4200.00
#
# ...

# %%
df['quantity'].corr(df['price'])
# Out:
# 0.3448798427911958

# %%
df.head(2)
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card   05/08/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul

# %%
y = df.price

# %%
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
import matplotlib.pyplot as plt
y= df.price
x=df.age
plt.plot(y, x)
plt.show()

# %%
features = ['age', 'quantity', 'gender']

# %%
X = df[features]
X
# Out:
#        age  quantity  gender
# 0       28         5  Female
# 1       21         3    Male
# 2       20         1    Male
# 3       66         5  Female
# 4       53         4  Female
# ...    ...       ...     ...
# 99452   45         5  Female
# 99453   27         2    Male
# 99454   63         2    Male
# 99455   56         4    Male
# 99456   36         3  Female
#
# [99457 rows x 3 columns]

# %%
y=df.price

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['gender_encoded'] = label_encoder.fit_transform(df['gender'])

from sklearn.tree import DecisionTreeRegressor
mymodel = DecisionTreeRegressor(random_state =1)
mymodel.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15620\159565744.py in ?()
#       4 df['gender_encoded'] = label_encoder.fit_transform(df['gender'])
#       5
#       6 from sklearn.tree import DecisionTreeRegressor
#       7 mymodel = DecisionTreeRegressor(random_state =1)
# ----> 8 mymodel.fit(X, y)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#    1316         self : DecisionTreeRegressor
#    1317             Fitted estimator.
# ...

# %%
X
# Out:
#        age  quantity  gender
# 0       28         5  Female
# 1       21         3    Male
# 2       20         1    Male
# 3       66         5  Female
# 4       53         4  Female
# ...    ...       ...     ...
# 99452   45         5  Female
# 99453   27         2    Male
# 99454   63         2    Male
# 99455   56         4    Male
# 99456   36         3  Female
#
# [99457 rows x 3 columns]

# %%
X = X.drop('gender', axis=1)

X
# Out:
#        age  quantity
# 0       28         5
# 1       21         3
# 2       20         1
# 3       66         5
# 4       53         4
# ...    ...       ...
# 99452   45         5
# 99453   27         2
# 99454   63         2
# 99455   56         4
# 99456   36         3
#
# [99457 rows x 2 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
mymodel = DecisionTreeRegressor(random_state=1)
mymodel.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
predictions = mymodel.predict(X)

# %%
predictions
# Out:
# array([1158.38368984,  695.79640704,  203.80290488, ...,  479.83047619,
#         925.84871391,  672.69789873])

# %%
y
# Out:
# 0        1500.40
# 1        1800.51
# 2         300.08
# 3        3000.85
# 4          60.60
#           ...
# 99452      58.65
# 99453      10.46
# 99454      10.46
# 99455    4200.00
# 99456      35.19
# Name: price, Length: 99457, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error

predictions = mymodel.predict(X)
error=mean_absolute_error(y, predictions)

# %%
error
# Out:
# 618.4292091866919
