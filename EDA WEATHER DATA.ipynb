# %% [markdown]
# <a href="https://colab.research.google.com/github/Etim-Antai/DataTheater/blob/main/EDA%20WEATHER%20DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis of Weather Data

# %% [markdown]
# # Import Liberaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import Data

# %%
dataset =pd.read_csv("/content/weather.csv")

# %% [markdown]
# # Obtain the first five rows of the data

# %%
dataset.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# # Get the shape of the data

# %%
dataset.shape
# Out:
# (366, 22)

# %%
#Get the basic infomation about the Data
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
# Get thecolumns of the Data
dataset.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
# Extract on the Numerical part of the data
adataset2 =dataset.select_dtypes(include ='number')
adataset2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0        8.0     24.3       0.0          3.4       6.3           30.0
# 1       14.0     26.9       3.6          4.4       9.7           39.0
# 2       13.7     23.4       3.6          5.8       3.3           85.0
# 3       13.3     15.5      39.8          7.2       9.1           54.0
# 4        7.6     16.1       2.8          5.6      10.6           50.0
# ..       ...      ...       ...          ...       ...            ...
# 361      9.0     30.7       0.0          7.6      12.1           76.0
# 362      7.1     28.4       0.0         11.6      12.7           48.0
# 363     12.5     19.9       0.0          8.4       5.3           43.0
# 364     12.5     26.9       0.0          5.0       7.1           46.0
# 365     12.3     30.2       0.0          6.0      12.6           78.0
#
#      WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
# Obtain the Statistical information about the data
dataset.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
# Obtain data Distribution of a particular column
dataset['WindGustDir'].value_counts()
# Out:
# WindGustDir
# NW     73
# NNW    44
# E      37
# WNW    35
# ENE    30
# ESE    23
# S      22
# N      21
# W      20
# NE     16
# SSE    12
# SE     12
# NNE     8
# SSW     5
# SW      3
# WSW     2
# Name: count, dtype: int64

# %%
# Get the number of empty cells in the data
dataset.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
adataset2 =dataset.select_dtypes(include ='number')

# %%
dataset2.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0      8.0     24.3       0.0          3.4       6.3           30.0
# 1     14.0     26.9       3.6          4.4       9.7           39.0
# 2     13.7     23.4       3.6          5.8       3.3           85.0
# 3     13.3     15.5      39.8          7.2       9.1           54.0
# 4      7.6     16.1       2.8          5.6      10.6           50.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0           6.0            20           68           29       1019.7
# 1           4.0            17           80           36       1012.4
# 2           6.0             6           82           69       1009.5
# 3          30.0            24           62           56       1005.5
# 4          20.0            28           68           49       1018.3
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RISK_MM
# 0       1015.0         7         7     14.4     23.6      3.6
# ...

# %%
dataset.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (366, 22)

# %%
dataset.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
dataset[dataset['WindDir9am'].isnull()]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 113     12.7     28.6       6.6          3.2       8.6           W
# 118     11.7     27.6       0.0          7.8       8.1           W
# 127     10.8     29.2       0.0          8.4       7.5           E
# 138     12.5     29.9       0.0          5.8      10.7          NW
# 140     11.5     29.3       0.0          5.2       8.0          NW
# 174      7.5     19.0       0.0          4.0       6.8         ENE
# 176      5.0     20.9       0.0          2.0       8.9         WNW
# 180     -2.1     13.8       0.2          1.8       9.5         NNW
# 189     -0.2     18.1       0.0          4.4       9.4          NW
# 195      2.2     18.6       0.0          2.0       9.2         NNW
# 200     -2.7     18.1       0.0          2.2       9.3           W
# 208      4.9     18.1       5.2          1.2       8.5         NNW
# 209      1.4     16.8       0.0          1.6       8.2          NW
# ...

# %% [markdown]
# dataset['WindDir9am']

# %%
dataset[dataset['WindSpeed9am'].isnull()]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 113     12.7     28.6       6.6          3.2       8.6           W
# 118     11.7     27.6       0.0          7.8       8.1           W
# 127     10.8     29.2       0.0          8.4       7.5           E
# 195      2.2     18.6       0.0          2.0       9.2         NNW
# 213      0.6     14.0       0.0          2.2       2.7          NE
# 247     -0.1     14.2       0.0          1.4       7.0           W
# 257     -1.7     13.6       0.0          1.8       5.2         NNW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 113           50.0        NaN          W           NaN  ...           42
# 118           48.0        NaN          W           NaN  ...           25
# 127           50.0        NaN        ENE           NaN  ...           34
# 195           31.0        NaN        NNW           NaN  ...           44
# ...

# %%
dataset['WindSpeed9am'].describe().round() #ave=9.651811
# Out:
# count    359.0
# mean      10.0
# std        8.0
# min        0.0
# 25%        6.0
# 50%        7.0
# 75%       13.0
# max       41.0
# Name: WindSpeed9am, dtype: float64

# %%
dataset['WindSpeed9am'].fillna(dataset['WindSpeed9am'].mean(), inplace = True)

# %%
dataset['WindSpeed9am'].mean()
# Out:
# 9.651810584958216

# %%
dataset[(dataset['WindSpeed9am']) >=9.65]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 6        6.1     18.2       0.2          4.2       8.4          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# ..       ...      ...       ...          ...       ...         ...
# 355      9.0     20.6       0.0          9.0       6.2         ENE
# 356      3.4     15.0       0.8          4.8      11.7           S
# 357      3.2     18.0       0.0          7.4      12.2         SSE
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 3             54.0        WNW          W          30.0  ...           56
# ...

# %%
dataset.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      0
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
dataset[dataset['WindGustSpeed'].isnull()]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 211     -0.1     18.0       0.0          2.0       8.6         NaN
# 271      0.8     12.2       0.0          1.8       8.6         NaN
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 211            NaN          N        NNW           2.0  ...           46
# 271            NaN          S          S          19.0  ...           49
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 211       1033.2       1028.7         1         1      5.6     17.4
# 271       1020.9       1016.8         3         1      6.5     11.2
#
#      RainToday  RISK_MM RainTomorrow
# 211         No      0.0           No
# 271         No      0.0           No
#
# [2 rows x 22 columns]

# %%
dataset
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
dataset.iloc[271]
# Out:
# MinTemp             0.8
# MaxTemp            12.2
# Rainfall            0.0
# Evaporation         1.8
# Sunshine            8.6
# WindGustDir         NaN
# WindGustSpeed       NaN
# WindDir9am            S
# WindDir3pm            S
# WindSpeed9am       19.0
# WindSpeed3pm         22
# Humidity9am          69
# Humidity3pm          49
# Pressure9am      1020.9
# Pressure3pm      1016.8
# Cloud9am              3
# Cloud3pm              1
# Temp9am             6.5
# Temp3pm            11.2
# RainToday            No
# RISK_MM             0.0
# RainTomorrow         No
# Name: 271, dtype: object

# %%
dataset['WindSpeed9am'].fillna(dataset['WindSpeed9am'].mean(), inplace = True)

# %%
dataset['WindGustSpeed'].describe()
# Out:
# count    364.000000
# mean      39.840659
# std       13.059807
# min       13.000000
# 25%       31.000000
# 50%       39.000000
# 75%       46.000000
# max       98.000000
# Name: WindGustSpeed, dtype: float64

# %%
dataset['WindGustSpeed'].mean()
# Out:
# 39.84065934065934

# %%
dataset['WindGustSpeed'].fillna(dataset['WindGustSpeed'].mean(), inplace = True)

# %%
dataset['WindDir3pm'].dtypes
# Out:
# dtype('O')

# %%
dataset.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
dataset2 =dataset.select_dtypes(include=['number'])

# %%
dataset2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0        8.0     24.3       0.0          3.4       6.3           30.0
# 1       14.0     26.9       3.6          4.4       9.7           39.0
# 2       13.7     23.4       3.6          5.8       3.3           85.0
# 3       13.3     15.5      39.8          7.2       9.1           54.0
# 4        7.6     16.1       2.8          5.6      10.6           50.0
# ..       ...      ...       ...          ...       ...            ...
# 361      9.0     30.7       0.0          7.6      12.1           76.0
# 362      7.1     28.4       0.0         11.6      12.7           48.0
# 363     12.5     19.9       0.0          8.4       5.3           43.0
# 364     12.5     26.9       0.0          5.0       7.1           46.0
# 365     12.3     30.2       0.0          6.0      12.6           78.0
#
#      WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
sns.heatmap(dataset2)
# Out:
# <Axes: >

# %%
dataset2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0        8.0     24.3       0.0          3.4       6.3           30.0
# 1       14.0     26.9       3.6          4.4       9.7           39.0
# 2       13.7     23.4       3.6          5.8       3.3           85.0
# 3       13.3     15.5      39.8          7.2       9.1           54.0
# 4        7.6     16.1       2.8          5.6      10.6           50.0
# ..       ...      ...       ...          ...       ...            ...
# 361      9.0     30.7       0.0          7.6      12.1           76.0
# 362      7.1     28.4       0.0         11.6      12.7           48.0
# 363     12.5     19.9       0.0          8.4       5.3           43.0
# 364     12.5     26.9       0.0          5.0       7.1           46.0
# 365     12.3     30.2       0.0          6.0      12.6           78.0
#
#      WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
X=dataset2.drop(['Sunshine','WindGustSpeed','WindSpeed9am','RISK_MM'], axis =1)
y=dataset2['RISK_MM']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test, y_train, y_test =train_test_split(X, y, test_size =0.6, random_state =0)

# %%
mymodel=LinearRegression()

# %%
mymodel.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions =mymodel.predict(X_test)

# %%
(predictions -y_test).round()
# Out:
# 106     1.0
# 259     4.0
# 45      8.0
# 26      2.0
# 78    -16.0
#        ...
# 61      1.0
# 67      4.0
# 316    -1.0
# 194    -0.0
# 154     0.0
# Name: RISK_MM, Length: 220, dtype: float64

# %%
mymodel.score(X_test, y_test)
# Out:
# 0.08168102463242
